# %% [markdown]
# # MPA-MLF, Lab 6 - Feedforward Neural Networks with regularization techniques and hyperparameter tunning

# %% [markdown]
# ## Exercise 1 - Classification of an images

# %% [markdown]
# The goal of this task will be to create Multi-layer perceptron model, that is able to recognize the  CIFAR10 dataset (https://www.cs.toronto.edu/~kriz/cifar.html). The CIFAR10 dataset consist of 60000 images with resolution of 32x32 pixels. There are 10 classes in total - *airplane*, *automobile*, *bird*, *cat*, *deer*, *dog*, *frog*, *horse*, *ship*, *truck*

# %% [markdown]
# These is an example of the dataset:

# %% [markdown]
# ![cifar10.png](data:image/png;base64,...)

# %% [markdown]
# ### 0. Import libraries

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import SGD
from keras.datasets import cifar10
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import cv2

# %% [markdown]
# ### 1. Load the Dataset
# The dataset is already a part of the Keras library, so we can quickly load it using the following command

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# The following numbered labels represent the labels in the dataset:

# %%
labels = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

# %% [markdown]
# ### 2. Data Examination

# %% [markdown]
# Fistly, lets have a look and the couple of images we have,

# %%
def display_random_images(x_data: np.array, y_data: np.array, count: int = 10) -> None:
  index = np.array(len(x_data))
  selected_ind = np.random.choice(index, count)

  selected_img = x_data[selected_ind]
  selected_labels_encoded = y_data[selected_ind]
  selected_labels = [labels[x[0]] for x in selected_labels_encoded]

  concat_img = np.concatenate(selected_img, axis=1)

  plt.figure(figsize=(20,10))
  plt.imshow(concat_img)

  for id_label, label in enumerate(selected_labels):
    plt.text((32/2) + 32*id_label - len(label), 32*(5/4), label)
  plt.axis('off')
  plt.show()

# %%
display_random_images(X_train, y_train)

# %%
#check the shape of image dataset

X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# In our dataset, we have 60000 images with 32x32 resolution. Each image has three channels (R, G, B). We have 50000 images for training and 10000 images for testing. Each channel for each image has values from 0 - 255, where each number represents the pixel intensity.
# With the combination of intensities of R, G and B, you can display up to 16,777,216 different colours (256^3)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Here you can display each channel separately:

# %%
def display_channels_separately(image: np.array) -> None:

  plt.figure()
  fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(10, 5))


  axs[0].imshow(image[:,:,0],cmap='Reds')
  axs[1].imshow(image[:,:,1],cmap='Blues')
  axs[2].imshow(image[:,:,2],cmap='Greens')

  axs[3].imshow(image)

  plt.show()

# %%
display_channels_separately(X_train[0])

# %% [markdown]
# ### 3. Preprocessing of the images

# %% [markdown]
# For machine learning purposes, we have to preprocess our images. Firstly we need to scale our images, to scale intensity values from 0-1 (min-max scaling)

# %%
X_train_scaled = X_train.astype('float32') / 255.0

# %% [markdown]
# We need to one-hot-encode the labels in our ground truth variable as our second preprocessing.

# %%
y_train_encoded = to_categorical(y_train, num_classes=10)

# %% [markdown]
# ### 4. Define the model architecture

# %%
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3)))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# We will define *the Sequential* model as in our last exercise. This time we will use a different approach to determine the input layers. Instead of specifying the *input_dim* parameter in our first hidden layer, we will create a **Flatten** layer that takes our 32x32x3 image and reshapes it into 1x3072.
#
# We will specify ten neurons in our output layer because we have 10 possible outputs and a **softmax** activation function that returns us a probability distribution over the classes. The class with the highest probability is typically chosen as the predicted class for a given input.

# %% [markdown]
# Check the description of our model:

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       786,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 789,258 (3.01 MB)
#  Trainable params: 789,258 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The next step is to compile our model, we will use *categorical_crossentropy* as a loss function, *stochastic gradient descend* as an optimisation and we will be checking *the accuracy* metric.

# %%
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

# %% [markdown]
# ### 5. Train the model

# %% [markdown]
# Our model will be trained in the same way as in our last pc_labs,

# %%
history = model.fit(X_train_scaled, y_train_encoded, epochs=50, batch_size=128, validation_split = 0.2)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.2734 - loss: 2.0351 - val_accuracy: 0.3430 - val_loss: 1.8602
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.3413 - loss: 1.8415 - val_accuracy: 0.3788 - val_loss: 1.7533
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.3536 - loss: 1.7880 - val_accuracy: 0.3879 - val_loss: 1.7409
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.3629 - loss: 1.7682 - val_accuracy: 0.3853 - val_loss: 1.7175
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3744 - loss: 1.7384 - val_accuracy: 0.3940 - val_loss: 1.7157
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.3839 - loss: 1.7139 - val_accuracy: 0.4106 - val_loss: 1.6626
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.3870 - loss: 1.7128 - val_accuracy: 0.4120 - val_loss: 1.6767
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.3943 - loss: 1.6927 - val_accuracy: 0.4172 - val_loss: 1.6689
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.3965 - loss: 1.6825 - val_accuracy: 0.4162 - val_loss: 1.6496
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.3994 - loss: 1.6727 - val_accuracy: 0.4220 - val_loss: 1.6384
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4019 - loss: 1.6661 - val_accuracy: 0.4334 - val_loss: 1.6110
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4085 - loss: 1.6556 - val_accuracy: 0.4193 - val_loss: 1.6331
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4101 - loss: 1.6426 - val_accuracy: 0.4382 - val_loss: 1.5964
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4135 - loss: 1.6382 - val_accuracy: 0.4353 - val_loss: 1.5954
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4182 - loss: 1.6306 - val_accuracy: 0.4335 - val_loss: 1.5960
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4178 - loss: 1.6271 - val_accuracy: 0.4336 - val_loss: 1.5942
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4220 - loss: 1.6139 - val_accuracy: 0.4416 - val_loss: 1.5868
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4238 - loss: 1.6129 - val_accuracy: 0.4427 - val_loss: 1.5842
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4235 - loss: 1.6096 - val_accuracy: 0.4416 - val_loss: 1.5902
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.4246 - loss: 1.6061 - val_accuracy: 0.4510 - val_loss: 1.5848
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4271 - loss: 1.5988 - val_accuracy: 0.4494 - val_loss: 1.5617
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.4318 - loss: 1.5926 - val_accuracy: 0.4408 - val_loss: 1.5774
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4311 - loss: 1.5911 - val_accuracy: 0.4378 - val_loss: 1.5712
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.4284 - loss: 1.5980 - val_accuracy: 0.4445 - val_loss: 1.5653
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4340 - loss: 1.5782 - val_accuracy: 0.4463 - val_loss: 1.5672
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4365 - loss: 1.5816 - val_accuracy: 0.4551 - val_loss: 1.5586
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4333 - loss: 1.5829 - val_accuracy: 0.4321 - val_loss: 1.5827
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4375 - loss: 1.5728 - val_accuracy: 0.4493 - val_loss: 1.5528
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4401 - loss: 1.5685 - val_accuracy: 0.4426 - val_loss: 1.5654
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4372 - loss: 1.5671 - val_accuracy: 0.4567 - val_loss: 1.5455
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4401 - loss: 1.5599 - val_accuracy: 0.4543 - val_loss: 1.5426
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4416 - loss: 1.5573 - val_accuracy: 0.4501 - val_loss: 1.5551
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4385 - loss: 1.5646 - val_accuracy: 0.4651 - val_loss: 1.5354
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4445 - loss: 1.5524 - val_accuracy: 0.4464 - val_loss: 1.5575
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4458 - loss: 1.5479 - val_accuracy: 0.4498 - val_loss: 1.5530
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.4463 - loss: 1.5488 - val_accuracy: 0.4477 - val_loss: 1.5701
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4456 - loss: 1.5463 - val_accuracy: 0.4520 - val_loss: 1.5451
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4478 - loss: 1.5422 - val_accuracy: 0.4535 - val_loss: 1.5411
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.4488 - loss: 1.5449 - val_accuracy: 0.4502 - val_loss: 1.5427
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4493 - loss: 1.5384 - val_accuracy: 0.4438 - val_loss: 1.5693
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.4498 - loss: 1.5376 - val_accuracy: 0.4643 - val_loss: 1.5313
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.4498 - loss: 1.5367 - val_accuracy: 0.4565 - val_loss: 1.5372
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.4523 - loss: 1.5305 - val_accuracy: 0.4592 - val_loss: 1.5351
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.4517 - loss: 1.5318 - val_accuracy: 0.4548 - val_loss: 1.5371
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.4468 - loss: 1.5346 - val_accuracy: 0.4627 - val_loss: 1.5332
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.4543 - loss: 1.5308 - val_accuracy: 0.4543 - val_loss: 1.5444
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.4547 - loss: 1.5235 - val_accuracy: 0.4546 - val_loss: 1.5378
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.4555 - loss: 1.5179 - val_accuracy: 0.4572 - val_loss: 1.5434
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.4545 - loss: 1.5254 - val_accuracy: 0.4591 - val_loss: 1.5228
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.4543 - loss: 1.5235 - val_accuracy: 0.4475 - val_loss: 1.5495

# %%
from keras.callbacks import EarlyStopping
from keras.layers import Input

# Define the improved model architecture
improved_model = Sequential()
improved_model.add(Input(shape=(32, 32, 3))) # Corrected input definition
improved_model.add(Flatten())
improved_model.add(Dense(512, activation='relu')) # Increased neurons
improved_model.add(Dropout(0.3)) # Added more dropout
improved_model.add(Dense(256, activation='relu')) # Added another Dense layer
improved_model.add(Dropout(0.3)) # Added more dropout
improved_model.add(Dense(10, activation='softmax'))

improved_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 3072)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,707,274 (6.51 MB)
#  Trainable params: 1,707,274 (6.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the improved model
improved_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the improved model with more epochs and EarlyStopping
improved_history = improved_model.fit(X_train_scaled, y_train_encoded, epochs=100, batch_size=128, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - accuracy: 0.2458 - loss: 2.0536 - val_accuracy: 0.3143 - val_loss: 1.8874
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 39ms/step - accuracy: 0.2997 - loss: 1.9012 - val_accuracy: 0.3593 - val_loss: 1.8245
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.3271 - loss: 1.8486 - val_accuracy: 0.3793 - val_loss: 1.7592
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - accuracy: 0.3329 - loss: 1.8234 - val_accuracy: 0.3610 - val_loss: 1.7679
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 40ms/step - accuracy: 0.3443 - loss: 1.7950 - val_accuracy: 0.3851 - val_loss: 1.7300
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.3523 - loss: 1.7751 - val_accuracy: 0.3905 - val_loss: 1.7242
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.3585 - loss: 1.7580 - val_accuracy: 0.3935 - val_loss: 1.7076
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.3645 - loss: 1.7482 - val_accuracy: 0.4171 - val_loss: 1.6569
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.3731 - loss: 1.7338 - val_accuracy: 0.4081 - val_loss: 1.6825
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.3710 - loss: 1.7326 - val_accuracy: 0.4087 - val_loss: 1.6812
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.3751 - loss: 1.7251 - val_accuracy: 0.4190 - val_loss: 1.6588
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.3781 - loss: 1.7081 - val_accuracy: 0.4131 - val_loss: 1.6610
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.3861 - loss: 1.6968 - val_accuracy: 0.4014 - val_loss: 1.6820
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.3874 - loss: 1.6888 - val_accuracy: 0.4150 - val_loss: 1.6514
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.3900 - loss: 1.6816 - val_accuracy: 0.4258 - val_loss: 1.6456
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.3936 - loss: 1.6695 - val_accuracy: 0.4280 - val_loss: 1.6456
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.3937 - loss: 1.6690 - val_accuracy: 0.4320 - val_loss: 1.6317
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.3970 - loss: 1.6628 - val_accuracy: 0.4286 - val_loss: 1.6430
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.4020 - loss: 1.6544 - val_accuracy: 0.4390 - val_loss: 1.6217
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.4034 - loss: 1.6486 - val_accuracy: 0.4257 - val_loss: 1.6375
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.3996 - loss: 1.6532 - val_accuracy: 0.4267 - val_loss: 1.6362
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.4042 - loss: 1.6437 - val_accuracy: 0.4281 - val_loss: 1.6329
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.4049 - loss: 1.6429 - val_accuracy: 0.4258 - val_loss: 1.6225
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 43ms/step - accuracy: 0.4130 - loss: 1.6307 - val_accuracy: 0.4353 - val_loss: 1.6160
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 39ms/step - accuracy: 0.4059 - loss: 1.6340 - val_accuracy: 0.4358 - val_loss: 1.6132
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4080 - loss: 1.6372 - val_accuracy: 0.4414 - val_loss: 1.6191
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - accuracy: 0.4108 - loss: 1.6266 - val_accuracy: 0.4372 - val_loss: 1.6167
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 40ms/step - accuracy: 0.4177 - loss: 1.6165 - val_accuracy: 0.4441 - val_loss: 1.5916
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4125 - loss: 1.6241 - val_accuracy: 0.4446 - val_loss: 1.6026
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.4126 - loss: 1.6201 - val_accuracy: 0.4326 - val_loss: 1.6015
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.4173 - loss: 1.6139 - val_accuracy: 0.4437 - val_loss: 1.5845
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.4168 - loss: 1.6145 - val_accuracy: 0.4375 - val_loss: 1.6086
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4176 - loss: 1.6105 - val_accuracy: 0.4488 - val_loss: 1.5881
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - accuracy: 0.4164 - loss: 1.6032 - val_accuracy: 0.4530 - val_loss: 1.5768
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - accuracy: 0.4203 - loss: 1.5979 - val_accuracy: 0.4511 - val_loss: 1.5815
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 41ms/step - accuracy: 0.4162 - loss: 1.6053 - val_accuracy: 0.4416 - val_loss: 1.5929
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4198 - loss: 1.5935 - val_accuracy: 0.4337 - val_loss: 1.6142
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4230 - loss: 1.5904 - val_accuracy: 0.4457 - val_loss: 1.5861
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4228 - loss: 1.5968 - val_accuracy: 0.4526 - val_loss: 1.5917
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.4212 - loss: 1.5994 - val_accuracy: 0.4435 - val_loss: 1.5986
# Epoch 41/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4240 - loss: 1.5913 - val_accuracy: 0.4343 - val_loss: 1.6001
# Epoch 42/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4249 - loss: 1.5916 - val_accuracy: 0.4359 - val_loss: 1.5866
# Epoch 43/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4260 - loss: 1.5870 - val_accuracy: 0.4572 - val_loss: 1.5700
# Epoch 44/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.4281 - loss: 1.5821 - val_accuracy: 0.4527 - val_loss: 1.5853
# Epoch 45/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4300 - loss: 1.5776 - val_accuracy: 0.4508 - val_loss: 1.5750
# Epoch 46/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.4272 - loss: 1.5864 - val_accuracy: 0.4470 - val_loss: 1.5969
# Epoch 47/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4260 - loss: 1.5789 - val_accuracy: 0.4474 - val_loss: 1.5696
# Epoch 48/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4276 - loss: 1.5835 - val_accuracy: 0.4525 - val_loss: 1.5701
# Epoch 49/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4312 - loss: 1.5700 - val_accuracy: 0.4435 - val_loss: 1.5728
# Epoch 50/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 43ms/step - accuracy: 0.4296 - loss: 1.5751 - val_accuracy: 0.4428 - val_loss: 1.5793
# Epoch 51/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4313 - loss: 1.5705 - val_accuracy: 0.4513 - val_loss: 1.5673
# Epoch 52/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - accuracy: 0.4336 - loss: 1.5671 - val_accuracy: 0.4380 - val_loss: 1.5952
# Epoch 53/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 41ms/step - accuracy: 0.4340 - loss: 1.5647 - val_accuracy: 0.4492 - val_loss: 1.5763
# Epoch 54/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 44ms/step - accuracy: 0.4346 - loss: 1.5667 - val_accuracy: 0.4581 - val_loss: 1.5512
# Epoch 55/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4362 - loss: 1.5595 - val_accuracy: 0.4560 - val_loss: 1.5611
# Epoch 56/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step - accuracy: 0.4335 - loss: 1.5636 - val_accuracy: 0.4600 - val_loss: 1.5568
# Epoch 57/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.4347 - loss: 1.5636 - val_accuracy: 0.4554 - val_loss: 1.5690
# Epoch 58/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 42ms/step - accuracy: 0.4378 - loss: 1.5567 - val_accuracy: 0.4583 - val_loss: 1.5715
# Epoch 59/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.4370 - loss: 1.5579 - val_accuracy: 0.4583 - val_loss: 1.5788
# Epoch 60/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.4369 - loss: 1.5544 - val_accuracy: 0.4509 - val_loss: 1.5645
# Epoch 61/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.4381 - loss: 1.5503 - val_accuracy: 0.4583 - val_loss: 1.5600
# Epoch 62/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.4363 - loss: 1.5548 - val_accuracy: 0.4536 - val_loss: 1.5651
# Epoch 63/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - accuracy: 0.4398 - loss: 1.5515 - val_accuracy: 0.4590 - val_loss: 1.5774
# Epoch 64/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.4380 - loss: 1.5563 - val_accuracy: 0.4407 - val_loss: 1.5734

# %%
# Evaluate the improved model on the test set
improved_score = improved_model.evaluate(X_test, y_test_encoded, verbose=0)
print('Test loss (improved model):', improved_score[0])
print(f'Test accuracy (improved model): {improved_score[1]*100} %')
# Out:
# Test loss (improved model): 1.5373430252075195
# Test accuracy (improved model): 46.27000093460083 %

# %%
plt.figure()
plt.plot(improved_history.history['loss'], label='Train Loss')
plt.plot(improved_history.history['val_loss'], label='Validation Loss')
plt.title('Improved Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(improved_history.history['accuracy'], label='Train Accuracy')
plt.plot(improved_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Improved Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
show_the_best_predictions(improved_model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %% [markdown]
# ### 6. Model evaluation

# %%
X_test = X_test.astype('float32') / 255.0
y_test_encoded = to_categorical(y_test, num_classes=10)

# %%
score = model.evaluate(X_test, y_test_encoded, verbose=0)
print('Test loss:', score[0])
print(f'Test accuracy: {score[1]*100} %')
# Out:
# Test loss: 1.5317411422729492
# Test accuracy: 45.329999923706055 %

# %%
plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# As you can see from the evaluation above, we was able to achive approx. 30% of an accuracy. In other word approx. 70% of an images we classified wrongly. That is really bad!

# %% [markdown]
# Lets check the best predictions from our model:

# %%
def show_the_best_predictions(model, x_test: np.array, y_test: np.array, n_of_pred: int = 10) -> None:
  mapping = {0:'airplane',1:'automobile',2:'bird',3:'cat',4:'deer',5:'dog',6:'frog',7:'horse',8:'ship',9:'truck'}

  predictions = model.predict(x_test)
  y_test = y_test.reshape(1,-1)
  predictions_ind = np.argmax(predictions, axis=1)
  predictions_ind = predictions_ind.reshape(1, -1)

  corect_predictions = np.where(predictions_ind == y_test)

  rows_correct = corect_predictions[1]
  predictedtions_correct = predictions[rows_correct]
  target_correct = y_test[0][rows_correct]

  max_samples = predictions[rows_correct, target_correct]
  selected_images = x_test[rows_correct]
  sorted_ind = np.argsort(max_samples)[::-1]


  images = []
  prob = []
  labels = []


  for ind in range(n_of_pred):

    index = sorted_ind[ind]

    labels.append(target_correct[index])
    prob.append(max_samples[index])
    images.append(selected_images[index])

  plt.figure(figsize=(20,10))

  images = np.concatenate(np.asarray(images),axis=1)
  plt.imshow(images)
  for ins in range(n_of_pred):
    texts = '{}: \n{:.3f} %'.format(mapping[labels[ins]], prob[ins]*100)
    plt.text((32/2) + 32*ins - len(mapping[labels[ins]]), 32*(5/4), texts)

  plt.axis('off')
  plt.show()

# %%
show_the_best_predictions(model, X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# ### Task Description:

# %% [markdown]
# You task of this exercise would be to improve the model's performance to achieve better results in image classification task. There is no need to change the preprocessing of the dataset. There are possible way how to improve the models performance:

# %% [markdown]
# 1. Hyperparameter tunning - change the hyperparameters so that the model will perform better. You can experiment with the following:
#  - *changing the number of neurons in the hidden layer*
#  - *changing the number of hidden layers*
#  - *changing the activation functions*
#  - *changing the learning rate*
#  - *changing the optimizer* - So far, we have used only Gradient descend as our optimizer, but Keras offers other algorithms that can perform better - check the documentation!
#  - *changing the number of learning epochs*\
#  - *changing the batch size*
#
# 2. Regularization techniques - There are several regularization techniques that can improve the model's performance:
#  - *Dropout* -  In the Keras lib. you can add *dropout layer* into your Sequential model using the following command  *model.add(Dropout(p))* where *p* is an hyperparameter that controls dropout probabily, typical values are 0.1 - 0.5.
#  - *L1, L2 regularization* - In keras the regularization is applied for selected layers, there is an example how to add l2 regularization to an layer (for more details check the documnetation):  *model.add(Dense(64, activation='relu', input_dim=100, kernel_regularizer=l2(0.01)))*
#  - *Early stopping* -  In Keras, you can use the EarlyStopping callback to implement early stopping in your model. *early_stopping = EarlyStopping(monitor='val_loss', patience=3)*,  *model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), callbacks=[early_stopping])*

# %% [markdown]
# Try to make the highest testing accuracy possible. You can directly edit the code that is presented above, or you can copy everything into new cells. Please submit only the code with the best performance and briefly describe what approaches you have tried and what were the results

# %% [markdown]
# ### WRITE YOUR DESCRIPTION IN THIS CELL ###

# %% [markdown]
# ### Voluntary task:
# Implement one of the hyperparameter tunning algorithms discussed in the lecture, such as *Grid Search*, *Random Search* or more sophisticated ones. Some of these algorithms are already included in the Keras. Check the documentation
